# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("company_sales_data_matplotlib.csv")
total_profit_per_month = data.groupby('month_number')['total_profit'].sum()
plt.figure(figsize=(10, 6))
plt.plot(total_profit_per_month.index, total_profit_per_month.values, marker='o', linestyle='--', color='red', linewidth=2, label='Total Profit')
plt.title('Total Profit Over Months')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
